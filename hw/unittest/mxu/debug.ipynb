# %%
# block size 1
val=0x2aa80000
print(format(val, '030b'))
val=0x15540000
print(format(val, '030b'))
val=0xaaa0000
print(format(val, '030b'))
val=0x5550000
print(format(val, '030b'))

print(format(int(str("101010101010000000000000000000")[0:11], 2), "0x"))
print(format(int(str("010101010101000000000000000000")[1:12], 2), "0x"))
print(format(int(str("001010101010100000000000000000")[2:13], 2), "0x"))
print(format(int(str("000101010101010000000000000000")[3:14], 2), "0x"))

# %%
# block size 2 
val = 0x2aa80000
print(format(val, '030b'))
val = 0x15540000
print(format(val, '030b'))
val = 0xaaa0000
print(format(val, '030b'))
val = 0x5550000
print(format(val, '030b'))

print(format(int(str("101010101010000000000000000000")[0:14], 2), "0x"))
print(format(int(str("010101010101000000000000000000")[0:14], 2), "0x"))
print(format(int(str("001010101010100000000000000000")[2:16], 2), "0x"))
print(format(int(str("000101010101010000000000000000")[2:16], 2), "0x"))

# %%
# block size 3
val=0x2aa80000
print(format(val, '030b'))
val=0x15540000
print(format(val, '030b'))
val=0xaaa0000
print(format(val, '030b'))
val=0x5550000
print(format(val, '030b'))

print(format(int(str("101010101010000000000000000000")[0:15], 2), "0x"))
print(format(int(str("010101010101000000000000000000")[0:15], 2), "0x"))
print(format(int(str("001010101010100000000000000000")[0:15], 2), "0x"))
print(format(int(str("000101010101010000000000000000")[3:18], 2), "0x"))

# %%
# block size 4
val=0x2aa80000
print(format(val, '032b'))
val=0x15540000
print(format(val, '032b'))
val=0xaaa0000
print(format(val, '032b'))
val=0x5550000
print(format(val, '032b'))


print(format(int(str("00101010101010000000000000000000")[0:16], 2), "0x"))
print(format(int(str("00010101010101000000000000000000")[0:16], 2), "0x"))
print(format(int(str("00001010101010100000000000000000")[0:16], 2), "0x"))
print(format(int(str("00000101010101010000000000000000")[0:16], 2), "0x"))

# %%
# block size 5
val=0x2aa80000
print(format(val, '032b'))
val=0x15540000
print(format(val, '032b'))
val=0xaaa0000
print(format(val, '032b'))
val=0x5550000
print(format(val, '032b'))


print(format(int(str("101010101010000000000000000000")[0:20], 2), "0x"))
print(format(int(str("010101010101000000000000000000")[0:20], 2), "0x"))
print(format(int(str("001010101010100000000000000000")[0:20], 2), "0x"))
print(format(int(str("000101010101010000000000000000")[0:20], 2), "0x"))

# %%
import math
def get_block_num(block_size, shift, bitwidth):
    return ((shift + bitwidth - 1) // block_size) - (shift // block_size) + 1

full_bitwidth = 30
for block_size in range(1, full_bitwidth+1):
  shift = [i for i in range(block_size)]
  block_nums = [get_block_num(block_size, s, full_bitwidth) for s in shift]
  max_block_num = max(block_nums)
  offset = max_block_num - (math.ceil(full_bitwidth / block_size))
  print(f"block size : {block_size:2}, offset : {offset}")
