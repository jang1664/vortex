# %%
import yaml

# %%
data = yaml.safe_load(open("./generated_suites/prefill_merged/prefill_merged_naive_simd.yaml"))

# %%
apps = [(case['app'], case['args']) for case in data['cases']]

# %%
apps
# Out:
# [('eladd', '-n 2097152'),
#  ('elmul', '-n 5636096'),
#  ('head_concat', '-batch 1 -seq 512 -heads 32 -headdim 128'),
#  ('rmsnorm', '-batch 1 -seq 512 -hidden 4096'),
#  ('rope', '-batch 1 -seq 512 -heads 32 -headdim 128 -maxseq 4096 -offset 0'),
#  ('sgemm_tcu', '-m 512 -n 4096 -k 4096'),
#  ('sgemm_tcu', '-m 512 -n 512 -k 128'),
#  ('sgemm_tcu', '-m 512 -n 128 -k 512'),
#  ('sgemm_tcu', '-m 512 -n 11008 -k 4096'),
#  ('sgemm_tcu', '-m 512 -n 4096 -k 11008'),
#  ('silu', '-n 5636096'),
#  ('softmax', '-batch 1 -heads 32 -seqq 512 -seqk 512 -mask 1'),
#  ('detile_output', '-m 512 -n 4096'),
#  ('detile_output', '-m 512 -n 512'),
#  ('detile_output', '-m 512 -n 128'),
#  ('detile_output', '-m 512 -n 11008'),
#  ('tile_input_a', '-m 512 -k 4096'),
#  ('tile_input_a', '-m 512 -k 128'),
#  ('tile_input_a', '-m 512 -k 512'),
#  ('tile_input_a', '-m 512 -k 11008'),
#  ('tile_weight_w4a16', '-k 128 -n 512 -t 1'),
#  ('tile_weight_w4a16', '-k 512 -n 128 -t 0'),
# ...
